# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
for i in range(1,13):
  name = '/content/drive/My Drive/data/monthly data/'+str(i)+'.csv'
  
  if i ==1:
    flights = pd.read_csv(name)
  else:
    df = pd.read_csv(name)
    flights.append(df,ignore_index=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
flights
# Out:
#         YEAR  DAY_OF_MONTH  ...  LATE_AIRCRAFT_DELAY Unnamed: 29
# 0       2018            27  ...                  NaN         NaN
# 1       2018            27  ...                  NaN         NaN
# 2       2018            27  ...                  NaN         NaN
# 3       2018            27  ...                  NaN         NaN
# 4       2018            27  ...                  NaN         NaN
# ...      ...           ...  ...                  ...         ...
# 570113  2018            11  ...                  NaN         NaN
# 570114  2018            11  ...                  NaN         NaN
# 570115  2018            11  ...                  NaN         NaN
# 570116  2018            11  ...                 56.0         NaN
# 570117  2018            11  ...                  NaN         NaN
#
# [570118 rows x 30 columns]

# %%
flights.to_csv('flights-12.csv',index=False)

# %%
code_iata = pd.read_csv('/content/drive/My Drive/data/code-iata.csv')

# %%
#flights = pd.read_csv("/content/drive/My Drive/data/Flights.csv")

# %%
airports_code = pd.read_csv("/content/drive/My Drive/data/AirportCode.csv")

# %%
airports = pd.read_csv("/content/drive/My Drive/data/airports.csv")

# %%
airports_code = airports_code.iloc[:-1,:]

# %%
airports_code
# Out:
#        Code                                     Description
# 0     10001          Afognak Lake, AK: Afognak Lake Airport
# 1     10003   Granite Mountain, AK: Bear Creek Mining Strip
# 2     10004                        Lik, AK: Lik Mining Camp
# 3     10005          Little Squaw, AK: Little Squaw Airport
# 4     10006                      Kizhuyak, AK: Kizhuyak Bay
# ...     ...                                             ...
# 6486  16826                         Witkowo, Poland: Powidz
# 6487  16827              Maniwaki, Canada: Maniwaki Airport
# 6488  16828       Essington, PA: Philadelphia Seaplane Base
# 6489  16829     West Palm Beach, FL: Palm Beach County Park
# 6490  16830  Port Washington, NY: Sands Point Seaplane Base
#
# [6491 rows x 2 columns]

# %%
airports[airports['iata']== 'LAX']
# Out:
#      iata                       name  ...   latitude   longitude
# 2039  LAX  Los Angeles International  ...  33.942536 -118.408074
#
# [1 rows x 7 columns]

# %%
airports_code['city'] = [x.split(', ')[0] for x in airports_code['Description']]

# %%
airports_code['state'] = [x.split(', ')[1].split(': ')[0] for x in airports_code['Description']]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
airports_code['name'] = [x.split(': ')[1] for x in airports_code['Description']]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
airports_code
# Out:
#        Code  ...                        name
# 0     10001  ...        Afognak Lake Airport
# 1     10003  ...     Bear Creek Mining Strip
# 2     10004  ...             Lik Mining Camp
# 3     10005  ...        Little Squaw Airport
# 4     10006  ...                Kizhuyak Bay
# ...     ...  ...                         ...
# 6486  16826  ...                      Powidz
# 6487  16827  ...            Maniwaki Airport
# 6488  16828  ...  Philadelphia Seaplane Base
# 6489  16829  ...      Palm Beach County Park
# 6490  16830  ...   Sands Point Seaplane Base
#
# [6491 rows x 5 columns]

# %%
airports_code
# Out:
#        Code  ...                        name
# 0     10001  ...        Afognak Lake Airport
# 1     10003  ...     Bear Creek Mining Strip
# 2     10004  ...             Lik Mining Camp
# 3     10005  ...        Little Squaw Airport
# 4     10006  ...                Kizhuyak Bay
# ...     ...  ...                         ...
# 6486  16826  ...                      Powidz
# 6487  16827  ...            Maniwaki Airport
# 6488  16828  ...  Philadelphia Seaplane Base
# 6489  16829  ...      Palm Beach County Park
# 6490  16830  ...   Sands Point Seaplane Base
#
# [6491 rows x 5 columns]

# %%
airports_info = airports.merge(airports_code, left_on = ['city','state','name'],right_on=['city','state','name'])

# %%
flights_new = flights.merge(airports_info,left_on = 'ORIGIN_AIRPORT_ID',right_on='Code')

# %%
flights_new = flights_new.merge(airports_info,left_on = 'DEST_AIRPORT_ID',right_on='Code')

# %%
flights_new.columns
# Out:
# Index(['YEAR', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'FL_DATE', 'OP_UNIQUE_CARRIER',
#        'OP_CARRIER_FL_NUM', 'ORIGIN_AIRPORT_ID', 'DEST_AIRPORT_ID',
#        'CRS_DEP_TIME', 'DEP_TIME', 'TAXI_OUT', 'WHEELS_OFF', 'WHEELS_ON',
#        'TAXI_IN', 'ARR_TIME', 'ARR_DELAY', 'CANCELLED', 'CANCELLATION_CODE',
#        'DIVERTED', 'CRS_ELAPSED_TIME', 'ACTUAL_ELAPSED_TIME', 'AIR_TIME',
#        'FLIGHTS', 'DISTANCE', 'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY',
#        'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY', 'Unnamed: 29', 'iata_x',
#        'name_x', 'city_x', 'state_x', 'country_x', 'latitude_x', 'longitude_x',
#        'Code_x', 'Description_x', 'iata_y', 'name_y', 'city_y', 'state_y',
#        'country_y', 'latitude_y', 'longitude_y', 'Code_y', 'Description_y'],
#       dtype='object')

# %%
flights_new.columns = ['YEAR', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'FL_DATE', 'OP_UNIQUE_CARRIER',
       'OP_CARRIER_FL_NUM', 'ORIGIN_AIRPORT_ID', 'DEST_AIRPORT_ID',
       'CRS_DEP_TIME', 'DEP_TIME', 'TAXI_OUT', 'WHEELS_OFF', 'WHEELS_ON',
       'TAXI_IN', 'ARR_TIME', 'ARR_DELAY', 'CANCELLED', 'CANCELLATION_CODE',
       'DIVERTED', 'CRS_ELAPSED_TIME', 'ACTUAL_ELAPSED_TIME', 'AIR_TIME',
       'FLIGHTS', 'DISTANCE', 'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY',
       'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY', 'Unnamed: 29', 'iata_origin',
       'name_origin', 'city_origin', 'state_origin', 'country_origin', 'latitude_origin', 'longitude_origin',
       'Code_origin', 'Description_origin', 'iata_dest', 'name_dest', 'city_dest', 'state_dest',
       'country_dest', 'latitude_dest', 'longitude_dest', 'Code_dest', 'Description_dest']

# %%
flights_new.to_csv('flights_iata.csv',index = False)

# %%
flights_count = pd.DataFrame(flights_new.groupby(['iata_origin','iata_dest','OP_UNIQUE_CARRIER'])['FLIGHTS'].sum())

# %%
flights_count = flights_count.reset_index()

# %%
flights_count.columns = ['origin','destination','carrier','count']

# %%
flights_count_all = pd.DataFrame(flights_new.groupby(['iata_origin','iata_dest'])['FLIGHTS'].sum())

# %%
flights_count_all['carrier'] = 'all'

# %%
flights_count_all = flights_count_all.reset_index()

# %%
flights_count_all.columns = ['origin','destination','count','carrier']

# %%
flights_count = flights_count.append(flights_count_all, ignore_index=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
flights_delay
# Out:
#     carrier  delay origin
# 0        NK   -9.0    ACY
# 1        AS  -11.0    ANC
# 2        UA   -5.0    ANC
# 3        OO    9.5    AVL
# 4        9E  -19.5    BGR
# ..      ...    ...    ...
# 441     all   -3.0    TOL
# 442     all   -7.0    TPA
# 443     all   -9.0    TUL
# 444     all   -8.0    TUS
# 445     all   -8.5    TVC
#
# [446 rows x 3 columns]

# %%
flights_delay = pd.DataFrame(flights_new.groupby(['iata_origin','OP_UNIQUE_CARRIER'])['ARR_DELAY'].median())

# %%
flights_delay = flights_delay.reset_index()

# %%
flights_delay.columns = ['origin','carrier','delay']

# %%
flights_delay_all = pd.DataFrame(flights_new.groupby(['iata_origin'])['ARR_DELAY'].median())

# %%
flights_delay_all['carrier'] = 'all'

# %%
flights_delay_all = flights_delay_all.reset_index()

# %%
flights_delay_all.columns = ['origin','delay','carrier']

# %%
flights_delay = flights_delay.append(flights_delay_all, ignore_index=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
flights_airport = flights_delay.merge(flights_count,how='outer',on=['origin','carrier'])

# %%
flights_airport.to_csv('flights-aggregation.csv',index=False)

# %%
flights_airport
# Out:
#      carrier  delay origin  count destination
# 0         NK   -9.0    ACY   62.0         MCO
# 1         NK   -9.0    ACY   31.0         MYR
# 2         NK   -9.0    ACY   31.0         TPA
# 3         AS  -11.0    ANC   86.0         FAI
# 4         AS  -11.0    ANC  116.0         JNU
# ...      ...    ...    ...    ...         ...
# 1719     all   -8.0    TUS    4.0         OAK
# 1720     all   -8.0    TUS   93.0         ORD
# 1721     all   -8.0    TUS  246.0         PHX
# 1722     all   -8.0    TUS   66.0         SFO
# 1723     all   -8.5    TVC  149.0         ORD
#
# [1724 rows x 5 columns]

# %%
airports_info = airports.merge(airports_code, how = 'outer',on = ['city','state'])

# %%
airports_info.to_csv('airports_info.csv',index=False)

# %%
flights_new = flights.merge(code_iata,left_on = 'ORIGIN_AIRPORT_ID',right_on='code')

# %%
flights_new = flights_new.merge(code_iata,left_on = 'DEST_AIRPORT_ID',right_on='code')

# %%
flights_new.columns
# Out:
# Index(['YEAR', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'FL_DATE', 'OP_UNIQUE_CARRIER',
#        'OP_CARRIER_FL_NUM', 'ORIGIN_AIRPORT_ID', 'DEST_AIRPORT_ID',
#        'CRS_DEP_TIME', 'DEP_TIME', 'TAXI_OUT', 'WHEELS_OFF', 'WHEELS_ON',
#        'TAXI_IN', 'ARR_TIME', 'ARR_DELAY', 'CANCELLED', 'CANCELLATION_CODE',
#        'DIVERTED', 'CRS_ELAPSED_TIME', 'ACTUAL_ELAPSED_TIME', 'AIR_TIME',
#        'FLIGHTS', 'DISTANCE', 'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY',
#        'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY', 'Unnamed: 29', 'iata_x',
#        'code_x', 'iata_y', 'code_y'],
#       dtype='object')

# %%
flights_new.columns = ['YEAR', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'FL_DATE', 'OP_UNIQUE_CARRIER',
       'OP_CARRIER_FL_NUM', 'ORIGIN_AIRPORT_ID', 'DEST_AIRPORT_ID',
       'CRS_DEP_TIME', 'DEP_TIME', 'TAXI_OUT', 'WHEELS_OFF', 'WHEELS_ON',
       'TAXI_IN', 'ARR_TIME', 'ARR_DELAY', 'CANCELLED', 'CANCELLATION_CODE',
       'DIVERTED', 'CRS_ELAPSED_TIME', 'ACTUAL_ELAPSED_TIME', 'AIR_TIME',
       'FLIGHTS', 'DISTANCE', 'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY',
       'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY', 'Unnamed: 29', 'iata_origin',
       'code_origin', 'iata_dest', 'code_dest']

# %%
flights_count = pd.DataFrame(flights_new.groupby(['iata_origin','iata_dest','OP_UNIQUE_CARRIER'])['FLIGHTS'].sum())

# %%
flights_count = flights_count.reset_index()

# %%
flights_count.columns = ['origin','destination','carrier','count']

# %%
flights_count_all = pd.DataFrame(flights_new.groupby(['iata_origin','iata_dest'])['FLIGHTS'].sum())

# %%
flights_count_all['carrier'] = 'all'

# %%
flights_count_all = flights_count_all.reset_index()

# %%
flights_count_all.columns = ['origin','destination','count','carrier']

# %%
flights_count = flights_count.append(flights_count_all, ignore_index=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
flights_delay = pd.DataFrame(flights_new.groupby(['iata_origin','OP_UNIQUE_CARRIER'])['ARR_DELAY'].median())

# %%
flights_delay = flights_delay.reset_index()

# %%
flights_delay.columns = ['origin','carrier','delay']

# %%
flights_delay_all = pd.DataFrame(flights_new.groupby(['iata_origin'])['ARR_DELAY'].median())

# %%
flights_delay_all['carrier'] = 'all'

# %%
flights_delay_all = flights_delay_all.reset_index()

# %%
flights_delay_all.columns = ['origin','delay','carrier']

# %%
flights_delay = flights_delay.append(flights_delay_all, ignore_index=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
flights_airport = flights_delay.merge(flights_count,how='outer',on=['origin','carrier'])

# %%
flights_airport
# Out:
#       carrier  delay origin  count destination
# 0          AA  -10.5    ABQ   31.0         ORD
# 1          AS   -4.0    ABQ    3.0         SEA
# 2          B6   -6.5    ABQ   19.0         JFK
# 3          DL  -19.0    ABQ   50.0         ATL
# 4          DL  -19.0    ABQ    2.0         MSP
# ...       ...    ...    ...    ...         ...
# 10224     all  -12.0    WRG   31.0         KTN
# 10225     all  -12.0    WRG   31.0         PSG
# 10226     all  -25.0    YAK   30.0         CDV
# 10227     all  -25.0    YAK   30.0         JNU
# 10228     all   -8.0    YUM  121.0         PHX
#
# [10229 rows x 5 columns]

# %%
flights_airport.to_csv('flights-aggregation.csv',index=False)

# %%
flights = pd.read_csv("/content/drive/My Drive/data/flights-12.csv")

# %%
flights1 = flights[['DAY_OF_WEEK','OP_UNIQUE_CARRIER', 'ARR_DELAY']]

# %%
df2 = flights1[flights1['ARR_DELAY'] > 0].groupby(['OP_UNIQUE_CARRIER','DAY_OF_WEEK']).count().reset_index()

# %%
df1 = flights1.groupby(['OP_UNIQUE_CARRIER','DAY_OF_WEEK']).count().reset_index()

# %%
df = df1.merge(df2, on=['DAY_OF_WEEK','OP_UNIQUE_CARRIER'])

# %%
df['delay_rate'] = df['ARR_DELAY_y']/df['ARR_DELAY_x']

# %%
df.to_csv('delay_rate.csv',index=False)
